# %%
# ===========================================
# Deep Feed Forward Network for Classification
# Breast Cancer Dataset
# ===========================================

# Import Libraries
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# -----------------------------
# Load Dataset
# -----------------------------
data = load_breast_cancer()

X = data.data          # Input features
y = data.target        # Target (0 = Malignant, 1 = Benign)

# -----------------------------
# Train-Test Split
# -----------------------------
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,       # 20% testing data
    random_state=42
)

# -----------------------------
# Feature Scaling
# -----------------------------
scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# -----------------------------
# Build Deep Feed Forward Network
# -----------------------------
model = Sequential()

# Hidden Layer 1
model.add(Dense(64, activation='relu', input_shape=(X_train.shape[1],)))

# Hidden Layer 2
model.add(Dense(32, activation='relu'))

# Hidden Layer 3
model.add(Dense(16, activation='relu'))

# Output Layer (Binary Classification)
model.add(Dense(1, activation='sigmoid'))

# -----------------------------
# Compile Model
# -----------------------------
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# -----------------------------
# Train Model
# -----------------------------
history = model.fit(
    X_train,
    y_train,
    epochs=30,
    batch_size=32,
    validation_split=0.2,
    verbose=1
)

# -----------------------------
# Test Model
# -----------------------------
loss, accuracy = model.evaluate(X_test, y_test)

print("\nTest Accuracy :", accuracy)

# -----------------------------
# Predictions
# -----------------------------
predictions = model.predict(X_test)

# Convert probabilities to 0 or 1
predictions = (predictions > 0.5)

# -----------------------------
# Accuracy
# -----------------------------
print("\nAccuracy Score:")
print(accuracy_score(y_test, predictions))

# -----------------------------
# Confusion Matrix
# -----------------------------
print("\nConfusion Matrix:")
print(confusion_matrix(y_test, predictions))

# -----------------------------
# Classification Report
# -----------------------------
print("\nClassification Report:")
print(classification_report(y_test, predictions))

# -----------------------------
# Accuracy Graph
# -----------------------------
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title("Accuracy Graph")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# -----------------------------
# Loss Graph
# -----------------------------
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title("Loss Graph")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# -----------------------------
# Conclusion
# -----------------------------
print("\nModel trained and tested successfully.")
print("The confusion matrix and accuracy show the classification performance.")
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 6s 106ms/step - accuracy: 0.7225 - loss: 0.6230 - val_accuracy: 0.8901 - val_loss: 0.5094
# Epoch 2/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9341 - loss: 0.4435 - val_accuracy: 0.9670 - val_loss: 0.3616
# Epoch 3/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9533 - loss: 0.3029 - val_accuracy: 0.9670 - val_loss: 0.2509
# Epoch 4/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9670 - loss: 0.2013 - val_accuracy: 0.9670 - val_loss: 0.1753
# Epoch 5/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9780 - loss: 0.1364 - val_accuracy: 0.9780 - val_loss: 0.1323
# Epoch 6/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9808 - loss: 0.0984 - val_accuracy: 0.9780 - val_loss: 0.1096
# Epoch 7/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9835 - loss: 0.0772 - val_accuracy: 0.9780 - val_loss: 0.0983
# Epoch 8/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - accuracy: 0.9835 - loss: 0.0647 - val_accuracy: 0.9780 - val_loss: 0.0922
# Epoch 9/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.9890 - loss: 0.0561 - val_accuracy: 0.9780 - val_loss: 0.0886
# Epoch 10/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - accuracy: 0.9918 - loss: 0.0503 - val_accuracy: 0.9780 - val_loss: 0.0844
# Epoch 11/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9918 - loss: 0.0457 - val_accuracy: 0.9780 - val_loss: 0.0808
# Epoch 12/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9918 - loss: 0.0414 - val_accuracy: 0.9780 - val_loss: 0.0794
# Epoch 13/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9918 - loss: 0.0383 - val_accuracy: 0.9780 - val_loss: 0.0770
# Epoch 14/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9945 - loss: 0.0351 - val_accuracy: 0.9780 - val_loss: 0.0768
# Epoch 15/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9945 - loss: 0.0321 - val_accuracy: 0.9780 - val_loss: 0.0740
# Epoch 16/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9945 - loss: 0.0291 - val_accuracy: 0.9670 - val_loss: 0.0738
# Epoch 17/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9945 - loss: 0.0271 - val_accuracy: 0.9780 - val_loss: 0.0723
# Epoch 18/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.9945 - loss: 0.0249 - val_accuracy: 0.9670 - val_loss: 0.0714
# Epoch 19/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - accuracy: 0.9945 - loss: 0.0232 - val_accuracy: 0.9780 - val_loss: 0.0703
# Epoch 20/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9945 - loss: 0.0213 - val_accuracy: 0.9670 - val_loss: 0.0723
# Epoch 21/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9945 - loss: 0.0200 - val_accuracy: 0.9780 - val_loss: 0.0707
# Epoch 22/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9945 - loss: 0.0184 - val_accuracy: 0.9670 - val_loss: 0.0734
# Epoch 23/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9945 - loss: 0.0171 - val_accuracy: 0.9670 - val_loss: 0.0745
# Epoch 24/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9945 - loss: 0.0161 - val_accuracy: 0.9670 - val_loss: 0.0760
# Epoch 25/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9945 - loss: 0.0145 - val_accuracy: 0.9670 - val_loss: 0.0756
# Epoch 26/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9973 - loss: 0.0132 - val_accuracy: 0.9670 - val_loss: 0.0777
# Epoch 27/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9945 - loss: 0.0127 - val_accuracy: 0.9670 - val_loss: 0.0819
# Epoch 28/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9973 - loss: 0.0110 - val_accuracy: 0.9670 - val_loss: 0.0802
# Epoch 29/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9973 - loss: 0.0101 - val_accuracy: 0.9670 - val_loss: 0.0819
# Epoch 30/30
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9973 - loss: 0.0096 - val_accuracy: 0.9670 - val_loss: 0.0845
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9561 - loss: 0.1130
#
# Test Accuracy : 0.9561403393745422
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
#
# Accuracy Score:
# 0.956140350877193
#
# Confusion Matrix:
# [[40  3]
#  [ 2 69]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94        43
#            1       0.96      0.97      0.97        71
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114
# Model trained and tested successfully.
# The confusion matrix and accuracy show the classification performance.
